# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_parquet('data_complete.parquet')

# %%
data.head(10)
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SL  2024-10-15           89.7          -2.31           5.91
# 1         SI  2024-10-15           95.6          -2.02           6.13
# 2         FF  2024-10-15           97.7          -2.19           6.02
# 3         SI  2024-10-15           98.1          -2.47           5.76
# 4         FF  2024-10-15           97.4          -2.08           6.11
# 5         FC  2024-10-15           91.4          -2.21           5.95
# 6         SL  2024-10-15           89.4          -2.33           5.98
# 7         FF  2024-10-15           97.3          -2.28           5.96
# 8         CH  2024-10-15           88.0          -2.34           5.90
# 9         CH  2024-10-15           91.0          -2.26           5.85
#
#     player_name  batter  pitcher   events    description  ...  \
# 0  Cole, Gerrit  657041   543037     walk           ball  ...
# 1  Cole, Gerrit  657041   543037     None           foul  ...
# ...

# %%
plt.hist(data['release_speed'], bins=50)
# Out:
# (array([1.0000e+00, 5.0000e+00, 2.0000e+00, 6.0000e+00, 2.0000e+00,
#         1.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 3.0000e+00,
#         0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 2.0000e+00, 3.0000e+00, 2.0000e+00, 6.0000e+00,
#         1.0000e+00, 1.8000e+01, 3.1000e+01, 6.1000e+01, 2.0100e+02,
#         3.5000e+02, 5.9600e+02, 8.6300e+02, 1.3600e+03, 2.1020e+03,
#         3.5250e+03, 5.5040e+03, 6.6750e+03, 7.7920e+03, 8.9860e+03,
#         1.0532e+04, 1.2055e+04, 1.2366e+04, 1.0327e+04, 1.0098e+04,
#         1.1657e+04, 1.5477e+04, 1.8909e+04, 1.7080e+04, 1.2767e+04,
#         7.5540e+03, 2.9930e+03, 7.9700e+02, 1.3500e+02, 1.3000e+01]),
#  array([ 38.4  ,  39.708,  41.016,  42.324,  43.632,  44.94 ,  46.248,
#          47.556,  48.864,  50.172,  51.48 ,  52.788,  54.096,  55.404,
#          56.712,  58.02 ,  59.328,  60.636,  61.944,  63.252,  64.56 ,
#          65.868,  67.176,  68.484,  69.792,  71.1  ,  72.408,  73.716,
# ...

# %%
plt.hist(data['arm_angle'], bins=50)
# Out:
# (array([1.1000e+01, 2.7000e+01, 1.8000e+01, 5.7000e+01, 3.6000e+01,
#         5.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         4.0000e+00, 1.7000e+01, 1.9000e+01, 6.1000e+01, 6.4000e+01,
#         3.8000e+01, 7.7000e+01, 1.3700e+02, 1.4000e+02, 1.2200e+02,
#         1.0100e+02, 1.3100e+02, 1.7600e+02, 1.8800e+02, 2.3600e+02,
#         3.9800e+02, 6.6700e+02, 1.2770e+03, 2.0030e+03, 3.1340e+03,
#         4.2470e+03, 5.6790e+03, 7.7050e+03, 1.1063e+04, 1.4568e+04,
#         1.6536e+04, 1.7810e+04, 1.6030e+04, 1.4914e+04, 1.0386e+04,
#         6.5240e+03, 4.0730e+03, 2.7810e+03, 1.4250e+03, 6.4900e+02,
#         4.3100e+02, 3.2000e+02, 1.2700e+02, 3.7000e+01, 7.0000e+00]),
#  array([-69.5  , -66.456, -63.412, -60.368, -57.324, -54.28 , -51.236,
#         -48.192, -45.148, -42.104, -39.06 , -36.016, -32.972, -29.928,
#         -26.884, -23.84 , -20.796, -17.752, -14.708, -11.664,  -8.62 ,
#          -5.576,  -2.532,   0.512,   3.556,   6.6  ,   9.644,  12.688,
# ...

# %%
test = pd.DataFrame(data['pitch_type'].value_counts())
test
# Out:
#             count
# pitch_type
# FF          66506
# SL          31679
# SI          25383
# CH          19365
# CU          12228
# FC          11699
# ST           4926
# KC           4740
# FS           3646
# SV            522
# KN             48
# FA             38
# EP             24
# FO             23
# CS             19
# PO             10
# SC              7

# %%
plt.bar(data['pitch_type'], test['count'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.bar(data['pitch_type'], test['count'])
#
# File ~/PycharmProjects/baseballDashboard/.venv/lib/python3.9/site-packages/matplotlib/pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
#    2960         bottom=bottom,
#    2961         align=align,
#    2962         **({"data": data} if data is not None else {}),
#    2963         **kwargs,
#    2964     )
#
# ...
